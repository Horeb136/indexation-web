# %%
import json

with open('title.non_pos_index.json', 'r') as f:
        file = json.load(f)

print(file.keys())
# Out:
# dict_keys(['erreur', '404', 'interstyleparis', '243', 'pas', 'de', 'titre', 'mode', 'stylisme', 'défilés', 'créateurs', 'haute', 'couture', 'revoir', 'paris', 'fashion', 'week', 'tendances', '2023', '24', '25', 'dessiner', 'la', 'nos', 'conseils', 'aux', 'futurs', 'stylistes', 'anticiper', 'incubateurs', 'réseaux', 'web', 'lieux', 'histoire', 'photos', 'films', 'passion', 'infos', 'pro', 'emplois', 'stages', 'forum', 'publiez', 'votre', 'annonce', 'modélistes', 'couturières', 'modistes', 'news', 'formation', 'cours', 'styliste', 'a', 'distance', 'sélectionner', 'une', 'page', 'lua', 'entraide', 'serveur', 'jeu', 'aide', 'fr', 'r', 'rom156', 'têtard', 'messages', '6', 'score', 'réaction', '0', 'points', '5', 'bonjour', 'à', 'chaque', 'fois', 'que', 'j', 'essaye', 'créer', 'mes', 'job', 'le', 'menu', 'f4', 'ne', 's', 'ouvre', 'plus', 'et', 'm', 'sur', 'l', 'addons', 'darkrp', 'voici', 'gamemodes', 'gamemode', 'modules', 'base', 'cl_gamemode_functions', '23', 'attempt', 'to', 'index', '
# ...
